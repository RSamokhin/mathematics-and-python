# %%
import codecs
file = codecs.open('../../../Downloads/res.txt', 'r', encoding='utf-8')

result = []

for line in file:
    userLine = line.strip().split(',')
    user = dict()
    user['id'] = userLine[0]
    user['team'] = userLine[1]
    user['surname'] = userLine[2]
    user['name'] = userLine[3]
    user['email'] = userLine[4]
    result.append(user)
    
for r in result: print r['surname']
# Out:
# Фамилия
# Семенов
# Гильманов
# Кетова
# Хананашвили
# Me
# Мирзоян
# Аррыков
# Невров
# Скорятина
# Салтыков
# Марченков
# Тимаков
# Жигулевцева
# Тимаков
# Корнаухов
# Мцариашвили
# Беседина
# Щербань
# Гинз
# Тевосян
# Васильев
# Парамонов
# Мокрецов
# Селезнев
# Луганский
# Базаев
# Гукайло
# Филатова
# Петров
# Сенин
# Присяжная
# Щербатых
# Левина
# Карягина
# Гвоздева
# Син
# Ким
# Крюкова
# Зайдуллина
# Мардерфельд
# Коваль
# Абдулкадыров
# Антонченко
# Талайбек уулу
# Додонов
# Нестеренко
# Бушков
# Дорофеев
# Неприна
# Вараксин
# Игумнова
# Боскина
# Кот
# Шубина
# Антонов
# Пивоваров
# Гниленко
# Шахуов
# Воронцоы
# Семичаснова
# Кнопов
# Белоголовый
# Масленникова
# Матинян
# Азнаурян
# Храпов
# Абрамов
# Арцруни
# Тугаринова
# Кузнецова
# Мирзануров
# Савушкин
# Горбунов
# Шарамко
# Гайфутдинов
# Перельштейн
# Караблинов
# Смирнов
# Манджиева
# Серебренникова
# Мириева
# Юрченко
# Евсеева
# Вдовыдченко
# Давидян
# Хлоповских
# Иванов
# Биктимирова
# Недобежкин
# ...
